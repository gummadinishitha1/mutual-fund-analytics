# %% [markdown]
# # Mutual Fund EDA Analysis
#
# Complete EDA deliverable with 15+ exported charts for final reporting.

# %%
from pathlib import Path
from IPython.display import Image, HTML, display

OUTPUT_DIR = Path('../outputs')
chart_files = sorted(OUTPUT_DIR.glob('*.png'))
len(chart_files), [p.name for p in chart_files]

# %% [markdown]
# ## Key EDA Findings

# %% [markdown]
# **Finding 1:** SBI Mutual Fund dominates fund-house AUM with the highlighted Rs. 12.5L Cr reference; supporting chart: `aum_growth_by_fund_house_2022_2025.png`.

# %% [markdown]
# **Finding 2:** Monthly SIP inflow reaches the dataset high of Rs. 31,002 Cr in Dec 2025; supporting chart: `sip_inflow_jan2022_dec2025.png`.

# %% [markdown]
# **Finding 3:** Folio count almost doubles from 13.26 Cr in Jan 2022 to 26.12 Cr in Dec 2025; supporting chart: `folio_count_growth_jan2022_dec2025.png`.

# %% [markdown]
# **Finding 4:** The 2023 bull-run window shows broad positive NAV momentum across the top 40 schemes; supporting chart: `nav_indexed_growth_2022_2026.png`.

# %% [markdown]
# **Finding 5:** The 2024 correction windows interrupt the otherwise rising NAV path and create visible dispersion across schemes; supporting chart: `nav_trend_2022_2026.png`.

# %% [markdown]
# **Finding 6:** Category flows are uneven by month, with high-intensity inflow pockets concentrated in specific categories; supporting chart: `category_inflow_heatmap.png`.

# %% [markdown]
# **Finding 7:** SIP participation is concentrated in working-age investor bands; supporting chart: `investor_age_group_pie.png`.

# %% [markdown]
# **Finding 8:** SIP ticket sizes vary materially by age group, as shown by the box-plot spread and outliers; supporting chart: `sip_amount_box_by_age_group.png`.

# %% [markdown]
# **Finding 9:** Geographic SIP value is concentrated in a small group of leading states; supporting chart: `sip_amount_by_state.png`.

# %% [markdown]
# **Finding 10:** Equity portfolio exposure is led by a few large sectors, with Banking the largest aggregate allocation; supporting chart: `sector_allocation_donut.png`.

# %% [markdown]
# ## Chart Gallery

# %% [markdown]
# ### NAV trend analysis
#
# Daily NAV for 40 schemes with 2023 bull run and 2024 correction highlights.

# %%
display(Image(filename=str(OUTPUT_DIR / 'nav_trend_2022_2026.png')))

# %% [markdown]
# ### Indexed NAV growth
#
# Base-100 growth comparison across the same 40 schemes.

# %%
display(Image(filename=str(OUTPUT_DIR / 'nav_indexed_growth_2022_2026.png')))

# %% [markdown]
# ### 2023 NAV returns
#
# Scheme-level return ranking during the 2023 rally.

# %%
display(Image(filename=str(OUTPUT_DIR / 'nav_2023_return_by_scheme.png')))

# %% [markdown]
# ### 2024 NAV returns
#
# Scheme-level return ranking around the correction year.

# %%
display(Image(filename=str(OUTPUT_DIR / 'nav_2024_return_by_scheme.png')))

# %% [markdown]
# ### AUM grouped bar
#
# Grouped bar chart by fund house and year, highlighting SBI.

# %%
display(Image(filename=str(OUTPUT_DIR / 'aum_growth_by_fund_house_2022_2025.png')))

# %% [markdown]
# ### AUM market share
#
# 2025 fund-house market share.

# %%
display(Image(filename=str(OUTPUT_DIR / 'aum_market_share_2025.png')))

# %% [markdown]
# ### SIP inflow trend
#
# Monthly SIP trend with Dec 2025 high annotated.

# %%
display(Image(filename=str(OUTPUT_DIR / 'sip_inflow_jan2022_dec2025.png')))

# %% [markdown]
# ### Active SIP accounts
#
# Growth in active SIP accounts.

# %%
display(Image(filename=str(OUTPUT_DIR / 'active_sip_accounts_growth.png')))

# %% [markdown]
# ### Category inflow heatmap
#
# Monthly category inflow intensity.

# %%
display(Image(filename=str(OUTPUT_DIR / 'category_inflow_heatmap.png')))

# %% [markdown]
# ### Category cumulative inflow
#
# Cumulative net inflow by category.

# %%
display(Image(filename=str(OUTPUT_DIR / 'category_cumulative_net_inflow.png')))

# %% [markdown]
# ### Investor age distribution
#
# Age group distribution pie chart.

# %%
display(Image(filename=str(OUTPUT_DIR / 'investor_age_group_pie.png')))

# %% [markdown]
# ### SIP amount by age group
#
# SIP amount distribution by age group.

# %%
display(Image(filename=str(OUTPUT_DIR / 'sip_amount_box_by_age_group.png')))

# %% [markdown]
# ### Gender split
#
# Gender split by SIP amount.

# %%
display(Image(filename=str(OUTPUT_DIR / 'investor_gender_split.png')))

# %% [markdown]
# ### Income by age group
#
# Median income by age group.

# %%
display(Image(filename=str(OUTPUT_DIR / 'median_income_by_age_group.png')))

# %% [markdown]
# ### SIP amount by state
#
# Geographic SIP amount bar chart.

# %%
display(Image(filename=str(OUTPUT_DIR / 'sip_amount_by_state.png')))

# %% [markdown]
# ### T30 vs B30 split
#
# City tier split pie chart.

# %%
display(Image(filename=str(OUTPUT_DIR / 't30_b30_city_tier_pie.png')))

# %% [markdown]
# ### Folio growth
#
# Folio growth with milestones.

# %%
display(Image(filename=str(OUTPUT_DIR / 'folio_count_growth_jan2022_dec2025.png')))

# %% [markdown]
# ### NAV return correlation
#
# Pairwise return correlations for 10 selected funds.

# %%
display(Image(filename=str(OUTPUT_DIR / 'nav_return_correlation_matrix.png')))

# %% [markdown]
# ### Sector allocation
#
# Aggregated equity sector allocation.

# %%
display(Image(filename=str(OUTPUT_DIR / 'sector_allocation_donut.png')))

# %% [markdown]
# ### Top equity holdings
#
# Largest aggregate equity holdings.

# %%
display(Image(filename=str(OUTPUT_DIR / 'top_equity_holdings_by_market_value.png')))

# %% [markdown]
# ### Top 3-year returns
#
# Top schemes by 3-year return.

# %%
display(Image(filename=str(OUTPUT_DIR / 'top_15_schemes_3yr_return.png')))

# %% [markdown]
# ### Risk-return profile
#
# Scheme risk-return scatter plot.

# %%
display(Image(filename=str(OUTPUT_DIR / 'risk_return_profile_by_scheme.png')))

# %% [markdown]
# ## Interactive Plotly Charts

# %%
display(HTML(filename=str(OUTPUT_DIR / 'nav_trend_2022_2026_plotly.html')))

# %%
display(HTML(filename=str(OUTPUT_DIR / 'sip_inflow_jan2022_dec2025_plotly.html')))
