# %% [markdown]
# # Fund Performance Analytics
#
# This notebook computes daily returns, CAGR, Sharpe, Sortino, alpha/beta, maximum drawdown, a 0-100 composite scorecard, benchmark tracking error, and a top-5 benchmark comparison chart.

# %% [markdown]
# ## Top Fund Scorecard

# %%
import pandas as pd

scorecard = pd.read_csv(PROJECT_ROOT / 'reports' / 'performance_analytics' / 'fund_scorecard.csv')
scorecard.head(10)
# Out:
#    amfi_code                                        scheme_name  \
# 0     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 1     120505           ICICI Pru Midcap Fund - Regular - Growth
# 2     120843             Kotak Flexicap Fund - Regular - Growth
# 3     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 4     120504          ICICI Pru Bluechip Fund - Direct - Growth
# 5     119094                Axis Midcap Fund - Regular - Growth
# 6     119551          SBI Bluechip Fund - Regular Plan - Growth
# 7     148569      Mirae Asset Tax Saver Fund - Regular - Growth
# 8     119598         SBI Small Cap Fund - Regular Plan - Growth
# 9     101206      ABSL Frontline Equity Fund - Regular - Growth
#
#                  fund_house category sub_category     plan  fund_score  \
# 0            Mirae Asset MF   Equity    Large Cap  Regular   85.897436
# 1       ICICI Prudential MF   Equity      Mid Cap  Regular   82.435897
# 2         Kotak Mahindra MF   Equity    Flexi Cap  Regular   81.538462
# 3          HDFC Mutual Fund   Equity      Mid Cap  Regular   80.641026
# 4       ICICI Prudential MF   Equity    Large Cap   Direct   78.846154
# 5          Axis Mutual Fund   Equity      Mid Cap  Regular   78.076923
# 6           SBI Mutual Fund   Equity    Large Cap  Regular   73.717949
# 7            Mirae Asset MF   Equity         ELSS  Regular   73.205128
# 8           SBI Mutual Fund   Equity    Small Cap  Regular   67.179487
# 9  Aditya Birla Sun Life MF   Equity    Large Cap  Regular   66.923077
#
#    cagr_1yr  cagr_3yr  cagr_5yr  ...  max_drawdown  max_drawdown_peak_date  \
# 0  0.203607  0.340009       NaN  ...     -0.112657              2023-07-11
# 1  0.296047  0.317775       NaN  ...     -0.181885              2024-10-24
# 2  0.266571  0.295828       NaN  ...     -0.129740              2022-03-07
# 3  0.532324  0.324425       NaN  ...     -0.162172              2022-03-11
# 4  0.130643  0.324874       NaN  ...     -0.125883              2022-10-04
# 5  0.222611  0.351118       NaN  ...     -0.209609              2022-04-14
# 6  0.604373  0.304565       NaN  ...     -0.150124              2023-08-24
# 7  0.397518  0.291789       NaN  ...     -0.163967              2023-08-10
# 8  0.827761  0.266699       NaN  ...     -0.287060              2024-08-28
# 9  0.479241  0.289677       NaN  ...     -0.112916              2023-04-24
#
#    max_drawdown_trough_date  annualized_return  annualized_volatility  \
# 0                2023-10-20           0.193454               0.120250
# 1                2025-01-23           0.209246               0.163311
# 2                2022-04-13           0.194910               0.134543
# 3                2022-05-12           0.194558               0.160291
# 4                2023-05-30           0.151899               0.121592
# 5                2022-08-11           0.184990               0.164246
# 6                2024-02-05           0.165188               0.116365
# 7                2023-10-20           0.202531               0.149645
# 8                2025-05-14           0.216398               0.212730
# 9                2023-07-05           0.153472               0.123321
#
#    score_3yr_return score_sharpe score_alpha  score_expense_ratio  \
# 0         97.435897   100.000000   84.615385            43.589744
# 1         89.743590    92.307692   94.871795            64.102564
# 2         84.615385    97.435897   89.743590            46.153846
# 3         92.307692    84.615385   87.179487            61.538462
# 4         94.871795    74.358974   69.230769            71.794872
# 5        100.000000    79.487179   79.487179            61.538462
# 6         87.179487    89.743590   76.923077            25.641026
# 7         82.051282    94.871795   92.307692            10.256410
# 8         71.794872    69.230769  100.000000            48.717949
# 9         79.487179    76.923077   71.794872            10.256410
#
#    score_max_drawdown
# 0           82.051282
# 1           38.461538
# 2           69.230769
# 3           51.282051
# 4           71.794872
# 5           30.769231
# 6           58.974359
# 7           48.717949
# 8           10.256410
# 9           79.487179
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Alpha and Beta

# %%
alpha_beta = pd.read_csv(PROJECT_ROOT / 'reports' / 'performance_analytics' / 'alpha_beta.csv')
alpha_beta.head(10)
# Out:
#    amfi_code                                        scheme_name  \
# 0     119598         SBI Small Cap Fund - Regular Plan - Growth
# 1     149324              DSP Small Cap Fund - Regular - Growth
# 2     120505           ICICI Pru Midcap Fund - Regular - Growth
# 3     148569      Mirae Asset Tax Saver Fund - Regular - Growth
# 4     120843             Kotak Flexicap Fund - Regular - Growth
# 5     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 6     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 7     149323                 DSP Midcap Fund - Regular - Growth
# 8     119094                Axis Midcap Fund - Regular - Growth
# 9     119551          SBI Bluechip Fund - Regular Plan - Growth
#
#             fund_house category sub_category     plan     alpha      beta  \
# 0      SBI Mutual Fund   Equity    Small Cap  Regular  0.303370 -0.023196
# 1      DSP Mutual Fund   Equity    Small Cap  Regular  0.300579  0.011455
# 2  ICICI Prudential MF   Equity      Mid Cap  Regular  0.292636  0.000549
# 3       Mirae Asset MF   Equity         ELSS  Regular  0.282704  0.018134
# 4    Kotak Mahindra MF   Equity    Flexi Cap  Regular  0.273305 -0.022830
# 5     HDFC Mutual Fund   Equity      Mid Cap  Regular  0.271954  0.005104
# 6       Mirae Asset MF   Equity    Large Cap  Regular  0.269838  0.023684
# 7      DSP Mutual Fund   Equity      Mid Cap  Regular  0.265986 -0.002523
# 8     Axis Mutual Fund   Equity      Mid Cap  Regular  0.260767 -0.066265
# 9      SBI Mutual Fund   Equity    Large Cap  Regular  0.232010 -0.031751
#
#       r_squared  regression_p_value
# 0  1.414258e-04            0.687179
# 1  3.532991e-05            0.840494
# 2  1.345534e-07            0.990090
# 3  1.748889e-04            0.654295
# 4  3.430543e-04            0.530528
# 5  1.206652e-05            0.906369
# 6  4.625437e-04            0.466427
# 7  3.357978e-06            0.950525
# 8  1.936879e-03            0.135988
# 9  8.869789e-04            0.313143

# %% [markdown]
# ## Daily Return Distribution Validation

# %%
distribution = pd.read_csv(PROJECT_ROOT / 'reports' / 'performance_analytics' / 'daily_return_distribution.csv')
distribution[['amfi_code', 'count', 'mean', 'std', 'min', 'max', 'p01', 'p99', 'looks_reasonable']].head()
# Out:
#    amfi_code  count      mean       std       min       max       p01  \
# 0     100016   1607  0.000101  0.007749 -0.024744  0.032145 -0.019691
# 1     100025   1607  0.000122  0.002081 -0.008188  0.008837 -0.005360
# 2     100033   1607  0.000772  0.010097 -0.044238  0.041954 -0.024628
# 3     101206   1607  0.000609  0.007768 -0.038121  0.033956 -0.017510
# 4     101207   1607  0.000303  0.013741 -0.051847  0.054851 -0.034725
#
#         p99  looks_reasonable
# 0  0.020912              True
# 1  0.005618              True
# 2  0.027292              True
# 3  0.021002              True
# 4  0.036606              True

# %% [markdown]
# ## CAGR Comparison

# %%
cagr = pd.read_csv(PROJECT_ROOT / 'reports' / 'performance_analytics' / 'cagr_comparison.csv')
cagr[['scheme_name', 'cagr_1yr', 'cagr_3yr', 'cagr_5yr', 'cagr_5yr_has_full_period']].head(10)
# Out:
#                                          scheme_name  cagr_1yr  cagr_3yr  \
# 0                Axis Midcap Fund - Regular - Growth  0.222611  0.351118
# 1      Mirae Asset Large Cap Fund - Regular - Growth  0.203607  0.340009
# 2          ICICI Pru Bluechip Fund - Direct - Growth  0.130643  0.324874
# 3  HDFC Mid-Cap Opportunities Fund - Regular - Gr...  0.532324  0.324425
# 4           ICICI Pru Midcap Fund - Regular - Growth  0.296047  0.317775
# 5          SBI Bluechip Fund - Regular Plan - Growth  0.604373  0.304565
# 6             Kotak Flexicap Fund - Regular - Growth  0.266571  0.295828
# 7      Mirae Asset Tax Saver Fund - Regular - Growth  0.397518  0.291789
# 8      ABSL Frontline Equity Fund - Regular - Growth  0.479241  0.289677
# 9              DSP Small Cap Fund - Regular - Growth  0.651387  0.270004
#
#    cagr_5yr  cagr_5yr_has_full_period
# 0       NaN                     False
# 1       NaN                     False
# 2       NaN                     False
# 3       NaN                     False
# 4       NaN                     False
# 5       NaN                     False
# 6       NaN                     False
# 7       NaN                     False
# 8       NaN                     False
# 9       NaN                     False

# %% [markdown]
# ## Tracking Error

# %%
tracking_error = pd.read_csv(PROJECT_ROOT / 'reports' / 'performance_analytics' / 'tracking_error_top5.csv')
tracking_error
# Out:
#    amfi_code                                        scheme_name  \
# 0     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 1     148567      Mirae Asset Large Cap Fund - Regular - Growth
# 2     120505           ICICI Pru Midcap Fund - Regular - Growth
# 3     120505           ICICI Pru Midcap Fund - Regular - Growth
# 4     120843             Kotak Flexicap Fund - Regular - Growth
# 5     120843             Kotak Flexicap Fund - Regular - Growth
# 6     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 7     100033  HDFC Mid-Cap Opportunities Fund - Regular - Gr...
# 8     120504          ICICI Pru Bluechip Fund - Direct - Growth
# 9     120504          ICICI Pru Bluechip Fund - Direct - Growth
#
#             fund_house benchmark  tracking_error  observations
# 0       Mirae Asset MF   NIFTY50        0.193996          1149
# 1       Mirae Asset MF  NIFTY100        0.189664          1149
# 2  ICICI Prudential MF   NIFTY50        0.233124          1149
# 3  ICICI Prudential MF  NIFTY100        0.231968          1149
# 4    Kotak Mahindra MF   NIFTY50        0.205148          1149
# 5    Kotak Mahindra MF  NIFTY100        0.206425          1149
# 6     HDFC Mutual Fund   NIFTY50        0.229755          1149
# 7     HDFC Mutual Fund  NIFTY100        0.228699          1149
# 8  ICICI Prudential MF   NIFTY50        0.191376          1149
# 9  ICICI Prudential MF  NIFTY100        0.191587          1149
